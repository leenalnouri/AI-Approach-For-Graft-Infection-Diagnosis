# %%
#Importing important libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso, LogisticRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.preprocessing import StandardScaler

# %%
#Loading the dataset
patients_data = pd.read_csv("plan b data.csv", index_col=0)

# %%
#Displaying patients features' table
patients_data
# Out:
#           Diagnosis  VisualG  SUVmax    TBR  ConclusionPET  ABusepostoper  \
# Patients
# 1                 1        4     6.7   3.72              2              1
# 2                 1        3     9.8   4.90              1              1
# 3                 1        3     5.3   4.42              1              1
# 4                 1        4    11.2  10.18              1              1
# 5                 1        4     9.1   6.59              1              1
# 6                 1        4     6.3   3.94              1              1
# 7                 1        4     4.9   4.45              1              1
# 8                 1        4     6.1   4.69              1              1
# 9                 1        3    10.3   2.86              1              1
# 10                1        2     7.5   2.88              3              1
# 11                0        0     4.9   2.89              2              1
# ...

# %%
#In practice, feature selection should be done after data pre-processing, so ideally, all the categorical variables are encoded into numbers
numerics = ['int16','int32','int64','float16','float32','float64']
numerical_vars = list(patients_data.select_dtypes(include=numerics).columns)
patients_data = patients_data[numerical_vars]
patients_data
# Out:
#           Diagnosis  VisualG  SUVmax    TBR  ConclusionPET  ABusepostoper  \
# Patients
# 1                 1        4     6.7   3.72              2              1
# 2                 1        3     9.8   4.90              1              1
# 3                 1        3     5.3   4.42              1              1
# 4                 1        4    11.2  10.18              1              1
# 5                 1        4     9.1   6.59              1              1
# 6                 1        4     6.3   3.94              1              1
# 7                 1        4     4.9   4.45              1              1
# 8                 1        4     6.1   4.69              1              1
# 9                 1        3    10.3   2.86              1              1
# 10                1        2     7.5   2.88              3              1
# 11                0        0     4.9   2.89              2              1
# ...

# %%
#Separating the data into training and tests set
X_train, X_test, y_train, y_test = train_test_split(patients_data.drop(labels=['Diagnosis'], axis=1),
    patients_data['Diagnosis'],
    test_size=0.3,
    random_state=0)
X_train, X_test
# Out:
# (          VisualG  SUVmax    TBR  ConclusionPET  ABusepostoper  \
#  Patients
#  23              1     2.4   3.43              2              2
#  6               4     6.3   3.94              1              1
#  17              2     4.8   2.18              3              2
#  9               3    10.3   2.86              1              1
#  15              3     4.3   2.15              2              1
#  24              1     3.4   1.70              2              2
#  21              1     3.0   1.67              2              2
#  2               3     9.8   4.90              1              1
#  30              1     2.5   1.92              2              2
#  7               4     4.9   4.45              1              1
#  5               4     9.1   6.59              1              1
#  19              0     9.3   7.75              2              2
#  20              2     4.3   3.07              2              2
# ...

# %%
#Scaling the data
scaler = StandardScaler()
scaler.fit(X_train.fillna(0))
# Out:
# StandardScaler()

# %%
#Selecting features using Lasso regularisation using SelectFromModel
sel_ = SelectFromModel(LogisticRegression(C=1, penalty='l1', solver='liblinear'))
sel_.fit(scaler.transform(X_train.fillna(0)), y_train)
# Out:
# SelectFromModel(estimator=LogisticRegression(C=1, penalty='l1',
#                                              solver='liblinear'))

# %%
#Visualising features that were kept by the lasso regularisation
sel_.get_support()
# Out:
# array([False, False, False,  True,  True,  True, False, False, False,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True])

# %%
#In the above output, the output labels are index wise. So True is for the features that lasso thought is important (non-zero features) while False is for the features whose weights were shrinked to zero and are not important according to Lasso.

# %%
selected_feat = X_train.columns[(sel_.get_support())]
print('total features: {}'.format((X_train.shape[1])))
print('selected features: {}'.format(len(selected_feat)))
print('features with coefficients shrank to zero: {}'.format(
      np.sum(sel_.estimator_.coef_ == 0)))
# Out:
# total features: 106
# selected features: 7
# features with coefficients shrank to zero: 99

# %%
#visualizing the selected features
selected_feat
# Out:
# Index(['ConclusionPET', 'ABusepostoper', 'minimum_intensity', 'quantile0025',
#        'information_measure_of_correlation1_max', 'long_run_emphasis_mean',
#        'filter_$'],
#       dtype='object')

# %%
np.sum(sel_.estimator_.coef_ == 0)
# Out:
# 99

# %%
#Identifying the removed features
removed_feats = X_train.columns[(sel_.estimator_.coef_ == 0).ravel().tolist()]
removed_feats
# Out:
# Index(['VisualG', 'SUVmax', 'TBR', 'maximum_intensity', 'range',
#        'mean_intensity', 'quantile25', 'median_intensity', 'quantile75',
#        'quantile975', 'sum', 'variance', 'standard_deviation', 'skewness',
#        'kurtosis', 'energy', 'entropy', 'mean_absolute_deviation',
#        'root_mean_square', 'uniformity', 'autocorrection_mean',
#        'autocorrection_max', 'contrast_mean', 'contrast_max',
#        'correlation_mean', 'correlation_max', 'haralicks_correlation_mean',
#        'haralicks_correlation_max', 'cluster_prominence_mean',
#        'cluster_prominence_max', 'cluster_shade_mean', 'cluster_shade_max',
#        'cluster_tendency_mean', 'cluster_tendency_max', 'dissimilarity_mean',
#        'dissimilarity_max', 'energy_mean', 'energy_A', 'entropy_mean',
#        'entropy_max', 'homogeneity1_mean', 'homogeneity1_max',
#        'homogeneity2_mean', 'homogeneity2_max', 'maximum_probability_mean',
# ...

# %%
#Removing the features from the training and testing set
X_train_selected = sel_.transform(X_train.fillna(0))
X_test_selected = sel_.transform(X_test.fillna(0))
X_train_selected.shape, X_test_selected.shape
# Out:
# ((21, 7), (9, 7))
